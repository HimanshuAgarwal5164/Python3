# %% [markdown]
# # For clear images(no noise), Our OCR works perfectly fine

# %%
import PIL
from PIL import Image
from IPython.display import display
import pytesseract

# %%
img = Image.open(r"C:\Users\Himanshu Agarwal\Pictures\Saved Pictures\text1.jpg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=615x409 at 0x2501ADC5B88>

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Text Message
# Today 15:46
#
# Its Emma. | tried to call you but
# signal bad. | been taken to
# hospital after having a fall this
# morning. If possible can you do
# me a quick favour and text me x

# %%
img2 = Image.open(r"C:\Users\Himanshu Agarwal\Pictures\Saved Pictures\text2.png")
display(img2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=646x250 at 0x2501AE72D08>

# %%
text2 = pytesseract.image_to_string(img2)
print(text2)
# Out:
# GET IT ON
# ye Google Play

# %%
img3 = Image.open(r"C:\Users\Himanshu Agarwal\Pictures\Saved Pictures\whatsapp1.jpeg")
display(img3)
text3 = pytesseract.image_to_string(img3)
print(text3)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x251 at 0x2501B076E88>
# Figuring out if | should do my work or sit and think if |
# should do my work.
#
# 20//
#
# [Knowns Only]
