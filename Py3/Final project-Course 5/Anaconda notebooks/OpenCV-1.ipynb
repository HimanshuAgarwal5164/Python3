# %%
import cv2 as cv

# %%
img = cv.imread(r"C:\Users\Himanshu Agarwal\Pictures\Saved Pictures\Me.jpg")

# %%
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
from PIL import Image

# %%
image = Image.fromarray(gray,'L')
display(image)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x22DCBE36288>

# %%
#Exercise- Load and display an image using openCV

img = cv.imread(r"C:\Users\Himanshu Agarwal\Pictures\Saved Pictures\Me3.jpg")
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

image = Image.fromarray(gray,'L')
display(image)
# Out:
# <PIL.Image.Image image mode=L size=950x960 at 0x22DCCF7B288>
